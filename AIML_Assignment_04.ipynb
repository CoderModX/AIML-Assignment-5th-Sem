# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
print("Matplotlib version:", matplotlib.__version__)
# Out:
# Matplotlib version: 3.5.3

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
x = df['Embarked'].value_counts()
print(x.index,x.values)
# Out:
# Index(['S', 'C', 'Q'], dtype='object') [644 168  77]

# %% [markdown]
# # Matplotlib

# %%
male = df['Sex'].value_counts()['male']
female = df['Sex'].value_counts()['female']
fare = df['Fare'].mean()

bar_name = ['Male','Female', 'Mean of Fare']

count = [male,female,fare]
color = ['coral','gold','deepskyblue']

# %%
fig = plt.figure(figsize = (10,7))
plt.bar(bar_name,count,color=color)
plt.show()

# %%
#Data
class_one = np.array(df[df['Pclass'] == 1]['Fare'])
class_two = np.array(df[df['Pclass'] == 2]['Fare'])
class_three = np.array(df[df['Pclass'] == 3]['Fare'])
class_one = np.sort(class_one)
class_two = np.sort(class_two)
class_three = np.sort(class_three)

# %%
#b
#fare = np.array(df['Fare'])
#fare = np.sort(fare)
plt.plot(class_one)
plt.show()

# %%
#c
#This shows fare prices for three classes
plt.plot(class_one)
plt.plot(class_two)
plt.plot(class_three)
plt.show()

# %%
#d
plt.hist(df['Age'])
fig.show()
# Out:
# C:\Users\Divyansh K. Pathak\AppData\Local\Temp\ipykernel_24864\1607569675.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#e
age = df['Age'].dropna()
fare = df['Fare'].dropna()
pclass = df['Pclass'].dropna()
fig = plt.figure(figsize=(6, 6))
plt.boxplot(age, labels=['Age']);

# %%
plt.boxplot(fare, labels=['Fare']);

# %%
plt.boxplot(pclass, labels=['Pclass']);

# %%
#f
plt.scatter(df['Age'],df['Fare'],color='gold')
plt.show()

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(df['Age'], df['Fare'], color = 'coral')

plt.show()

# %% [markdown]
# # Seaborn

# %%
#a
sns.scatterplot(data=df,x='Age',y='Fare',hue="Sex")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#b & c
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
#d
cm_surv = ["coral" , "skyblue"]
fig, ax = plt.subplots(figsize=(13,7))
sns.violinplot(x="Pclass", y="Age", hue='Survived', data=df, split=True, bw=0.05 , palette=cm_surv, ax=ax)
plt.title('Fares for Age and Pclass ')
plt.show()

# %%
#e
sns.kdeplot(data=df, x="Fare")
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>
